# %%
import cv2
import dlib
import numpy as np
import os
import imutils
from PIL import Image
import matplotlib.pyplot as pltac

# %%
#os.chdir("D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\CropTest - Review 2")
#path = "D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\CropTest - Review 2\4.png"

# %%
os.chdir("D:\\Documents\\Semester 6\\Deep Learning and Neural Networks\\Project\\Datasets\\Natural Emotions\\anger")
path = "D:\\Documents\\Semester 6\\Deep Learning and Neural Networks\\Project\\Datasets\\Natural Emotions\\anger\\images - 2020-11-05T231347.970_face.png"

# %%
img= cv2.imread("D:\\Documents\\Semester 6\\Deep Learning and Neural Networks\\Project\\Datasets\\Natural Emotions\\anger\\images - 2020-11-05T231347.970_face.png")
img = imutils.resize(img, width = 500)
gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(img)
# Out:
# [[[  5   5   5]
#   [  5   5   5]
#   [  5   5   5]
#   ...
#   [ 93  93  93]
#   [ 93  93  93]
#   [ 93  93  93]]
#
#  [[  5   5   5]
#   [  5   5   5]
#   [  5   5   5]
#   ...
#   [ 93  93  93]
#   [ 93  93  93]
#   [ 93  93  93]]
#
#  [[  5   5   5]
#   [  5   5   5]
#   [  5   5   5]
#   ...
#   [ 93  93  93]
#   [ 93  93  93]
#   [ 93  93  93]]
#
#  ...
#
#  [[ 45  45  45]
#   [ 45  45  45]
#   [ 45  45  45]
#   ...
#   [196 196 196]
#   [196 196 196]
#   [196 196 196]]
#
#  [[ 45  45  45]
#   [ 45  45  45]
#   [ 45  45  45]
#   ...
#   [196 196 196]
#   [196 196 196]
#   [196 196 196]]
#
#  [[ 45  45  45]
#   [ 45  45  45]
#   [ 45  45  45]
#   ...
#   [196 196 196]
#   [196 196 196]
#   [196 196 196]]]

# %%
plt.imshow(img)

# %%
img_copy=img.copy()

# %%
detector = dlib.get_frontal_face_detector()
faces = detector(gray, 1)

# %%
p = "D:\\Documents\\Semester 6\\Deep Learning and Neural Networks\\Project\\Datasets\\shape_predictor_68_face_landmarks.dat"
predictor = dlib.shape_predictor(p)

for face in faces:
    landmarks = predictor(gray, face)

# %%
"""
pointA=[((landmarks.part(1).x),(landmarks.part(20).y))]
pointB=[((landmarks.part(15).x),(landmarks.part(15).y))]

cropWindow=pointA+pointB
cropWindow=np.array(cropWindow,dtype=np.int32)

print(cropWindow)"""
# Out:
# '\npointA=[((landmarks.part(1).x),(landmarks.part(20).y))]\npointB=[((landmarks.part(15).x),(landmarks.part(15).y))]\n\ncropWindow=pointA+pointB\ncropWindow=np.array(cropWindow,dtype=np.int32)\n\nprint(cropWindow)'

# %%
if(landmarks.part(20).y>landmarks.part(25).y):
    pointA1=[((landmarks.part(1).x-20),(landmarks.part(20).y-50))]

else:
    pointA1=[((landmarks.part(1).x-20),(landmarks.part(25).y-50))]

pointB1=[((landmarks.part(16).x+20),(landmarks.part(31).y-40))]


if(pointA1[0][0]<0):
    pointA1[0][0]=0
cropWindow2=pointA1+pointB1
cropWindow2=np.array(cropWindow2,dtype=np.int32)

print(landmarks.part(20).y)
print(landmarks.part(25).y)
print(cropWindow2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9620/1104082075.py in <module>
#       9
#      10 if(pointA1[0][0]<0):
# ---> 11     pointA1[0][0]=0
#      12 cropWindow2=pointA1+pointB1
#      13 cropWindow2=np.array(cropWindow2,dtype=np.int32)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#lif(landmarks.part(20).y is None):
#    pointA1=[((landmarks.part(1).x-20),(landmarks.part(25).y)-50)]
#elif(landmarks.part(25).y is None):
#    pointA1=[((landmarks.part(1).x-20),(landmarks.part(20).y)-50)]

# %%
"""points = []
for i in range(1, 16):
    point = [landmarks.part(i).x, landmarks.part(i).y]
    points.append(point)
points=np.array(points,dtype=np.int32)"""
# Out:
# 'points = []\nfor i in range(1, 16):\n    point = [landmarks.part(i).x, landmarks.part(i).y]\n    points.append(point)\npoints=np.array(points,dtype=np.int32)'

# %%
"""fig, ax = plt.subplots()
x = points[:,0]
y = points[:,1]
ax.imshow(img, extent=[0, 500, 0, 500])
ax.plot(x, y, '--', linewidth=5, color='firebrick')"""
# Out:
# "fig, ax = plt.subplots()\nx = points[:,0]\ny = points[:,1]\nax.imshow(img, extent=[0, 500, 0, 500])\nax.plot(x, y, '--', linewidth=5, color='firebrick')"

# %%
plt.plot(cropWindow2[:,0], cropWindow2[:,1], color="white")
plt.imshow(img)
plt.show()

# %%
"""
crop_img1=img[cropWindow[0][1]:cropWindow[1][1],cropWindow[0][0]:cropWindow[1][0]]
plt.imshow(crop_img1)"""
# Out:
# '\ncrop_img1=img[cropWindow[0][1]:cropWindow[1][1],cropWindow[0][0]:cropWindow[1][0]]\nplt.imshow(crop_img1)'

# %%
crop_img2=img[cropWindow2[0][1]:cropWindow2[1][1],cropWindow2[0][0]:cropWindow2[1][0]]
plt.imshow(crop_img2)

# %%
#outputNameofImage = "D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\MaskTest\Masked\TestCrop.jpg"
#print("Saving output image to", outputNameofImage)
#cv2.imwrite(outputNameofImage, img)
