# %%
import cv2
import dlib
import numpy as np
import os
import imutils
import matplotlib.pyplot as plt
from glob import glob
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
os.chdir('D:\\Documents\\Semester 6\\Deep Learning and Neural Networks\\Project\\Datasets\\Dataset_700')
color_blue = (239,207,137)

# %%
mask_crop_anger = 'D:\\Documents\\Semester 6\\Deep Learning and Neural Networks\\Project\\Datasets\\Dataset_700\\Masked and Cropped\\anger_mask_crop'
mask_crop_happy = 'D:\\Documents\\Semester 6\\Deep Learning and Neural Networks\\Project\\Datasets\\Dataset_700\\Masked and Cropped\\happy_mask_crop'
mask_crop_sadness = 'D:\\Documents\\Semester 6\\Deep Learning and Neural Networks\\Project\\Datasets\\Dataset_700\\Masked and Cropped\\sad_mask_crop'
mask_crop_surprise = 'D:\\Documents\\Semester 6\\Deep Learning and Neural Networks\\Project\\Datasets\\Dataset_700\\Masked and Cropped\\surprise_mask_crop'
mask_crop_neutral = 'D:\\Documents\\Semester 6\\Deep Learning and Neural Networks\\Project\\Datasets\\Dataset_700\\Masked and Cropped\\neutral_mask_crop'
mask_crop_disgust = 'D:\\Documents\\Semester 6\\Deep Learning and Neural Networks\\Project\\Datasets\\Dataset_700\\Masked and Cropped\\disgust_mask_crop'
mask_crop_fear = 'D:\\Documents\\Semester 6\\Deep Learning and Neural Networks\\Project\\Datasets\\Dataset_700\\Masked and Cropped\\fear_mask_crop'

# %%
resize_anger = 'D:\\Documents\\Semester 6\\Deep Learning and Neural Networks\\Project\\Datasets\\Dataset_700\\Masked and Cropped\\Resized\\anger_mask_crop'
resize_happy = 'D:\\Documents\\Semester 6\\Deep Learning and Neural Networks\\Project\\Datasets\\Dataset_700\\Masked and Cropped\\Resized\\happy_mask_crop'
resize_sadness = 'D:\\Documents\\Semester 6\\Deep Learning and Neural Networks\\Project\\Datasets\\Dataset_700\\Masked and Cropped\\Resized\\sad_mask_crop'
resize_surprise = 'D:\\Documents\\Semester 6\\Deep Learning and Neural Networks\\Project\\Datasets\\Dataset_700\\Masked and Cropped\\Resized\\surprise_mask_crop'
resize_neutral = 'D:\\Documents\\Semester 6\\Deep Learning and Neural Networks\\Project\\Datasets\\Dataset_700\\Masked and Cropped\\Resized\\neutral_mask_crop'
resize_disgust = 'D:\\Documents\\Semester 6\\Deep Learning and Neural Networks\\Project\\Datasets\\Dataset_700\\Masked and Cropped\\Resized\\disgust_mask_crop'
resize_fear = 'D:\\Documents\\Semester 6\\Deep Learning and Neural Networks\\Project\\Datasets\\Dataset_700\\Masked and Cropped\\Resized\\fear_mask_crop'

# %%
for angry_img in os.listdir(mask_crop_anger):
  path = mask_crop_anger + '\\' + angry_img
  img = cv2.imread(path)
  
  if img is None:
    break
  img=cv2.resize(img,(224,90))

  # output
  outputNameofImage = resize_anger + '\\' + angry_img
  print("Saving output image to", outputNameofImage)
  cv2.imwrite(outputNameofImage, img)
# Out:
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\anger_mask_crop\anger_0.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\anger_mask_crop\anger_1.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\anger_mask_crop\anger_10.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\anger_mask_crop\anger_100.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\anger_mask_crop\anger_101.png
# ...

# %%
for happy_img in os.listdir(mask_crop_happy):
  path = mask_crop_happy + '\\' + happy_img
  img = cv2.imread(path)
  
  if img is None:
    break
  img=cv2.resize(img,(224,90))

  # output
  outputNameofImage = resize_happy + '\\' + happy_img
  print("Saving output image to", outputNameofImage)
  cv2.imwrite(outputNameofImage, img)
# Out:
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\happy_mask_crop\happiness_0.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\happy_mask_crop\happiness_1.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\happy_mask_crop\happiness_10.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\happy_mask_crop\happiness_100.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\happy_mask_crop\happiness_101.png
# ...

# %%
for sad_img in os.listdir(mask_crop_sadness):
  path = mask_crop_sadness + '\\' + sad_img
  img = cv2.imread(path)
  
  if img is None:
    break
  img=cv2.resize(img,(224,90))

  # output
  outputNameofImage = resize_sadness + '\\' + sad_img
  print("Saving output image to", outputNameofImage)
  cv2.imwrite(outputNameofImage, img)
# Out:
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\sad_mask_crop\sadness_0.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\sad_mask_crop\sadness_1.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\sad_mask_crop\sadness_10.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\sad_mask_crop\sadness_100.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\sad_mask_crop\sadness_101.png
# ...

# %%
for surprise_img in os.listdir(mask_crop_surprise):
  path = mask_crop_surprise + '\\' + surprise_img
  img = cv2.imread(path)
  
  if img is None:
    break
  img=cv2.resize(img,(224,90))

  # output
  outputNameofImage = resize_surprise + '\\' + surprise_img
  print("Saving output image to", outputNameofImage)
  cv2.imwrite(outputNameofImage, img)
# Out:
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\surprise_mask_crop\sadness_10.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\surprise_mask_crop\sadness_100.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\surprise_mask_crop\sadness_101.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\surprise_mask_crop\sadness_102.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\surprise_mask_crop\sadness_103.png
# ...

# %%
for neutral_img in os.listdir(mask_crop_neutral):
  path = mask_crop_neutral + '\\' + neutral_img
  img = cv2.imread(path)
  
  if img is None:
    break
  img=cv2.resize(img,(224,90))

  # output
  outputNameofImage = resize_neutral + '\\' + neutral_img
  print("Saving output image to", outputNameofImage)
  cv2.imwrite(outputNameofImage, img)
# Out:
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\neutral_mask_crop\neutrality_0.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\neutral_mask_crop\neutrality_1.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\neutral_mask_crop\neutrality_10.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\neutral_mask_crop\neutrality_100.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\neutral_mask_crop\neutrality_101.png
# ...

# %%
for disgust_img in os.listdir(mask_crop_disgust):
  path = mask_crop_disgust + '\\' + disgust_img
  img = cv2.imread(path)
  
  if img is None:
    break
  img=cv2.resize(img,(224,90))

  # output
  outputNameofImage = resize_disgust + '\\' + disgust_img
  print("Saving output image to", outputNameofImage)
  cv2.imwrite(outputNameofImage, img)
# Out:
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\disgust_mask_crop\disgust_1.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\disgust_mask_crop\disgust_10.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\disgust_mask_crop\disgust_100.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\disgust_mask_crop\disgust_101.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\disgust_mask_crop\disgust_102.png
# ...

# %%
for fear_img in os.listdir(mask_crop_fear):
  path = mask_crop_fear + '\\' + fear_img
  img = cv2.imread(path)
  
  if img is None:
    break
  img=cv2.resize(img,(224,90))

  # output
  outputNameofImage = resize_fear + '\\' + fear_img
  print("Saving output image to", outputNameofImage)
  cv2.imwrite(outputNameofImage, img)
# Out:
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\fear_mask_crop\fear_0.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\fear_mask_crop\fear_1.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\fear_mask_crop\fear_10.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\fear_mask_crop\fear_100.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\fear_mask_crop\fear_101.png
# Saving output image to D:\Documents\Semester 6\Deep Learning and Neural Networks\Project\Datasets\Dataset_700\Masked and Cropped\Resized\fear_mask_crop\fear_102.png
# ...
